# %% [markdown]
# # Snippets/Examples for practice
# These snippets/examples are shared to save typing and allow maximum play/tweaking time.  The snippets and examples are in raw text cells and should be copied into code cells to be used.  If you convert the raw cells to code cells and work directly in them then you stand to lose the clean snippet / example.

# %% [markdown]
# ### uncaptured open file command

# %% [raw]
# open("trumpTweets.json", "r")

# %%
#copy and paste the example above here

# %%
tweets=[]
with open("trumpTweets.json", "r") as f:
    for tweet in f:
        tweets.append(json.loads(tweet))
    print(len(tweets))
    print(tweets[1]["text"])

# %%
import json
inputFile=open("trumpTweets.json", "r")
line = json.loads(inputFile.readline())
print(json.dumps(line, indent = 4))
# Out:
# {
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id_str": null,
#     "possibly_sensitive": false,
#     "id": 725540988047876096,
#     "user": {
#         "time_zone": null,
#         "default_profile_image": false,
#         "is_translation_enabled": false,
#         "protected": false,
#         "lang": "en",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/224732878/1461363729",
#         "default_profile": true,
#         "id": 224732878,
#         "profile_background_color": "C0DEED",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "friends_count": 3670,
#         "profile_sidebar_fill_color": "DDEEF6",
#         "following": false,
#         "profile_background_tile": false,
#         "followers_count": 4673,
#         "profile_link_color": "0084B4",
#         "contributors_enabled": false,
#         "has_extended_profile": false,
#         "url": null,
#         "profile_sidebar_border_color": "C0DEED",
#         "utc_offset": null,
#         "verified": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/711370892090040321/D9IwBCts_normal.jpg",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "description": "FATHER USS NASHVILLE WW2, WAS IN THE DOLITTLE RAID, BROTHER USS ENTERPRISE,SON USS FLORIDA SUB. GO NAVY TRUMP 2016",
#         "listed_count": 108,
#         "location": "Texas, USA",
#         "id_str": "224732878",
#         "name": "melissa TRUMP 2016",
#         "favourites_count": 9471,
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/711370892090040321/D9IwBCts_normal.jpg",
#         "screen_name": "dembigmouthdems",
#         "created_at": "Thu Dec 09 18:47:17 +0000 2010",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "notifications": false,
#         "statuses_count": 29376,
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "follow_request_sent": false,
#         "is_translator": false,
#         "geo_enabled": true
#     },
#     "favorite_count": 0,
#     "coordinates": null,
#     "retweet_count": 11,
#     "id_str": "725540988047876096",
#     "contributors": null,
#     "favorited": false,
#     "place": null,
#     "geo": null,
#     "text": "RT @Campaign_Trump: #Trump billionaire is staying at Holiday Express. It's shows you he is just a nice plain no BS down to earth guy.  http\u2026",
#     "is_quote_status": true,
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "in_reply_to_status_id": null,
#     "retweeted_status": {
#         "in_reply_to_screen_name": null,
#         "id_str": "725540411171721217",
#         "in_reply_to_user_id": null,
#         "possibly_sensitive": false,
#         "id": 725540411171721217,
#         "user": {
#             "time_zone": "Central Time (US & Canada)",
#             "default_profile_image": false,
#             "is_translation_enabled": false,
#             "protected": false,
#             "lang": "en",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/3314758074/1461570113",
#             "default_profile": true,
#             "id": 3314758074,
#             "profile_background_color": "C0DEED",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "friends_count": 16084,
#             "profile_sidebar_fill_color": "DDEEF6",
#             "following": false,
#             "profile_background_tile": false,
#             "followers_count": 34935,
#             "profile_link_color": "0084B4",
#             "contributors_enabled": false,
#             "has_extended_profile": false,
#             "url": "https://t.co/XPafpJYLTk",
#             "profile_sidebar_border_color": "C0DEED",
#             "utc_offset": -18000,
#             "verified": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/724691974029090817/i9IAcPtx_normal.jpg",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "description": "JP Moore is an Executive Advisory Board member to Paul Manafort & Campaign. Confidant to Icahn Enterprises. Now moving to California State. @realDonaldTrump",
#             "listed_count": 312,
#             "location": "California, USA (former NY)",
#             "id_str": "3314758074",
#             "name": "JP Moore (REAL)",
#             "favourites_count": 9449,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/724691974029090817/i9IAcPtx_normal.jpg",
#             "screen_name": "Campaign_Trump",
#             "created_at": "Fri Aug 14 06:45:07 +0000 2015",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "expanded_url": "https://www.donaldjtrump.com/schedule",
#                             "display_url": "donaldjtrump.com/schedule",
#                             "url": "https://t.co/XPafpJYLTk",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "notifications": false,
#             "statuses_count": 1236,
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "follow_request_sent": false,
#             "is_translator": false,
#             "geo_enabled": false
#         },
#         "favorite_count": 14,
#         "coordinates": null,
#         "retweet_count": 11,
#         "favorited": false,
#         "contributors": null,
#         "place": null,
#         "quoted_status": {
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id_str": null,
#             "id": 725524257883697152,
#             "user": {
#                 "time_zone": "Eastern Time (US & Canada)",
#                 "default_profile_image": false,
#                 "is_translation_enabled": true,
#                 "protected": false,
#                 "lang": "en",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/25073877/1460170262",
#                 "default_profile": false,
#                 "id": 25073877,
#                 "profile_background_color": "6D5C18",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "friends_count": 40,
#                 "profile_sidebar_fill_color": "C5CEC0",
#                 "following": false,
#                 "profile_background_tile": true,
#                 "followers_count": 7805644,
#                 "profile_link_color": "0D5B73",
#                 "contributors_enabled": false,
#                 "has_extended_profile": false,
#                 "url": "https://t.co/mZB2hymxC9",
#                 "profile_sidebar_border_color": "BDDCAD",
#                 "utc_offset": -14400,
#                 "verified": true,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1980294624/DJT_Headshot_V2_normal.jpg",
#                 "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg",
#                 "description": "#MakeAmericaGreatAgain #Trump2016",
#                 "listed_count": 32937,
#                 "location": "New York, NY",
#                 "id_str": "25073877",
#                 "name": "Donald J. Trump",
#                 "favourites_count": 84,
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1980294624/DJT_Headshot_V2_normal.jpg",
#                 "screen_name": "realDonaldTrump",
#                 "created_at": "Wed Mar 18 13:46:38 +0000 2009",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     },
#                     "url": {
#                         "urls": [
#                             {
#                                 "expanded_url": "http://www.DonaldJTrump.com",
#                                 "display_url": "DonaldJTrump.com",
#                                 "url": "https://t.co/mZB2hymxC9",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     }
#                 },
#                 "notifications": false,
#                 "statuses_count": 31772,
#                 "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg",
#                 "follow_request_sent": false,
#                 "is_translator": false,
#                 "geo_enabled": true
#             },
#             "favorite_count": 7249,
#             "coordinates": null,
#             "retweet_count": 2257,
#             "id_str": "725524257883697152",
#             "contributors": null,
#             "favorited": false,
#             "place": null,
#             "geo": null,
#             "text": "I am in Indiana where we just had a great rally. Fantastic people! Staying at a Holiday Inn Express - new and clean, not bad!",
#             "is_quote_status": false,
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "in_reply_to_status_id": null,
#             "in_reply_to_user_id_str": null,
#             "lang": "en",
#             "retweeted": false,
#             "created_at": "Thu Apr 28 03:17:17 +0000 2016",
#             "entities": {
#                 "urls": [],
#                 "hashtags": [],
#                 "user_mentions": [],
#                 "symbols": []
#             },
#             "truncated": false,
#             "in_reply_to_user_id": null,
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>"
#         },
#         "geo": null,
#         "text": "#Trump billionaire is staying at Holiday Express. It's shows you he is just a nice plain no BS down to earth guy.  https://t.co/Nayyhhonr9",
#         "is_quote_status": true,
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "retweeted": false,
#         "in_reply_to_user_id_str": null,
#         "quoted_status_id_str": "725524257883697152",
#         "lang": "en",
#         "in_reply_to_status_id": null,
#         "created_at": "Thu Apr 28 04:21:28 +0000 2016",
#         "entities": {
#             "urls": [
#                 {
#                     "expanded_url": "https://twitter.com/realdonaldtrump/status/725524257883697152",
#                     "display_url": "twitter.com/realdonaldtrum\u2026",
#                     "url": "https://t.co/Nayyhhonr9",
#                     "indices": [
#                         115,
#                         138
#                     ]
#                 }
#             ],
#             "hashtags": [
#                 {
#                     "text": "Trump",
#                     "indices": [
#                         0,
#                         6
#                     ]
#                 }
#             ],
#             "user_mentions": [],
#             "symbols": []
#         },
#         "truncated": false,
#         "in_reply_to_status_id_str": null,
#         "quoted_status_id": 725524257883697152,
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>"
#     },
#     "in_reply_to_user_id_str": null,
#     "lang": "en",
#     "retweeted": false,
#     "created_at": "Thu Apr 28 04:23:46 +0000 2016",
#     "entities": {
#         "urls": [
#             {
#                 "expanded_url": "https://twitter.com/realdonaldtrump/status/725524257883697152",
#                 "display_url": "twitter.com/realdonaldtrum\u2026",
#                 "url": "https://t.co/Nayyhhonr9",
#                 "indices": [
#                     139,
#                     140
#                 ]
#             }
#         ],
#         "hashtags": [
#             {
#                 "text": "Trump",
#                 "indices": [
#                     20,
#                     26
#                 ]
#             }
#         ],
#         "user_mentions": [
#             {
#                 "screen_name": "Campaign_Trump",
#                 "name": "JP Moore (REAL)",
#                 "id_str": "3314758074",
#                 "id": 3314758074,
#                 "indices": [
#                     3,
#                     18
#                 ]
#             }
#         ],
#         "symbols": []
#     },
#     "truncated": false,
#     "in_reply_to_user_id": null,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>"
# }

# %%
tweets = []
with open("trumpTweets.json", "r") as inputFile:
    for line in inputFile:
        tweets.append(json.loads(line))

# %%
from collections import Counter

with open("trumpTweets.json", "r") as inputFile:
    count_all = Counter()
    for line in inputFile:
        tweet=json.loads(line)
        count_all.update(preprocess(tweet['text']))
    # Print the first 5 most frequent words
    print(count_all.most_common(5))
# Out:
# ['RT', '@Campaign_Trump', ':', '#Trump', 'billionaire', 'is', 'staying', 'at', 'Holiday', 'Express', '.', "It's", 'shows', 'you', 'he', 'is', 'just', 'a', 'nice', 'plain', 'no', 'BS', 'down', 'to', 'earth', 'guy', '.', 'http', '…']
# ['RT', '@Campaign_Trump', ':', '#Trump', 'billionaire', 'is', 'staying', 'at', 'Holiday', 'Express', '.', "It's", 'shows', 'you', 'he', 'is', 'just', 'a', 'nice', 'plain', 'no', 'BS', 'down', 'to', 'earth', 'guy', '.', 'http', '…']
# ['RT', '@CorrectRecord', ':', "#Trump's", 'false', 'claim', 'that', "Bush's", 'White', 'House', 'tried', 'to', 'silence', 'his', 'Iraq', 'War', 'opposition', ':', 'https://t.co/30kuzNMFB0', 'https://t', '…']
# ['RT', '@CorrectRecord', ':', "#Trump's", 'false', 'claim', 'that', "Bush's", 'White', 'House', 'tried', 'to', 'silence', 'his', 'Iraq', 'War', 'opposition', ':', 'https://t.co/30kuzNMFB0', 'https://t', '…']
# ["#Trump's", 'foreign', 'policy', ';', '#America', 'will', 'be', 'the', 'number', '1,', 'greatest', ',', 'bestest', ',', 'mostest', 'country', 'on', 'Earth', ',', 'for', 'ever', 'and', 'ever', '#BestWordsEver']
# ["#Trump's", 'foreign', 'policy', ';', '#America', 'will', 'be', 'the', 'number', '1,', 'greatest', ',', 'bestest', ',', 'mostest', 'country', 'on', 'Earth', ',', 'for', 'ever', 'and', 'ever', '#BestWordsEver']
# ['RT', '@Joyce_Karam', ':', '#Trump', ':', '"', 'ISIS', 'will', 'be', 'gone', 'very', 'quickly', '"', '.', 'Not', 'that', 'simple', ':', 'been', '14', 'years', 'on', 'war', 'in', 'Afghanistan', 'with', 'ground', 'troops', '&', 'amp', ';', 'Al-Q', '…']
# ['RT', '@Joyce_Karam', ':', '#Trump', ':', '"', 'ISIS', 'will', 'be', 'gone', 'very', 'quickly', '"', '.', 'Not', 'that', 'simple', ':', 'been', '14', 'years', 'on', 'war', 'in', 'Afghanistan', 'with', 'ground', 'troops', '&', 'amp', ';', 'Al-Q', '…']
# ['RT', '@wtfnewsamerica', ':', '#Trump', 'on', '#ForeignPolicy', 'We', 'will', 'only', 'use', 'our', '#troops', 'if', 'we', 'have', 'a', 'plan', 'for', 'victory', 'with', 'a', 'capital', '"', 'V', '"', '!', '#INPrimary', 'htt', '…']
# ['RT', '@wtfnewsamerica', ':', '#Trump', 'on', '#ForeignPolicy', 'We', 'will', 'only', 'use', 'our', '#troops', 'if', 'we', 'have', 'a', 'plan', 'for', 'victory', 'with', 'a', 'capital', '"', 'V', '"', '!', '#INPrimary', 'htt', '…']
# ['RT', '@Drudge_Report_', ':', '#TRUMP', '#SLAMS', '#GLOBALISM', '.', '.', '.', '.', '@DonaldJTrumpJr', '@erictrump', 'https://t.co/TQ4kshGPRD']
# ['RT', '@Drudge_Report_', ':', '#TRUMP', '#SLAMS', '#GLOBALISM', '.', '.', '.', '.', '@DonaldJTrumpJr', '@erictrump', 'https://t.co/TQ4kshGPRD']
# ['RT', '@TRUMP_PREZ', ':', '#Cruz', 'is', 'so', 'incredibly', 'desperate', '.', '#Fiorina', 'better', 'get', 'ready', 'for', 'a', 'stab', 'in', 'the', 'back', '.', '#CruzFiorina', '-', '1', 'VOTE', '#Trump', 'https', ':/', '…']
# ['RT', '@TRUMP_PREZ', ':', '#Cruz', 'is', 'so', 'incredibly', 'desperate', '.', '#Fiorina', 'better', 'get', 'ready', 'for', 'a', 'stab', 'in', 'the', 'back', '.', '#CruzFiorina', '-', '1', 'VOTE', '#Trump', 'https', ':/', '…']
# ['All', 'aboard', 'the', '#TrumpTrain', '.', 'Next', 'stop', '#INPrimary', '.', "Let's", 'get', '#Trump', 'to', '1237', 'so', 'he', 'can', '#MAGA', '.', '#PresidentTrump', 'https://t.co/wh0TEQSVll']
# ['All', 'aboard', 'the', '#TrumpTrain', '.', 'Next', 'stop', '#INPrimary', '.', "Let's", 'get', '#Trump', 'to', '1237', 'so', 'he', 'can', '#MAGA', '.', '#PresidentTrump', 'https://t.co/wh0TEQSVll']
# ['RT', '@lilblnde', ':', '@JohnKasich', 'missed', 'PA', '.', "'", 's', 'deadline', 'and', 'funny', 'he', 'WAS', 'ON', 'the', 'ballot', '!', '#stopthesteal', '#trump', '#imprisonkillary', '#dropoutcruz', 'https', ':/', '/', '…']
# ['RT', '@lilblnde', ':', '@JohnKasich', 'missed', 'PA', '.', "'", 's', 'deadline', 'and', 'funny', 'he', 'WAS', 'ON', 'the', 'ballot', '!', '#stopthesteal', '#trump', '#imprisonkillary', '#dropoutcruz', 'https', ':/', '/', '…']
# ['RT', '@OrigIntent', ':', 'Just', 'a', 'reminder', '.', 'If', 'a', 'candidate', 'can', '’', 't', 'win', '50', '%', 'in', 'his', 'home', 'state', ',', 'he', 'can', '’', 't', 'win', 'in', 'Nov', '.', '@slone', '@amrightnow', '#Trump', 'https://t.', '…']
# ['RT', '@OrigIntent', ':', 'Just', 'a', 'reminder', '.', 'If', 'a', 'candidate', 'can', '’', 't', 'win', '50', '%', 'in', 'his', 'home', 'state', ',', 'he', 'can', '’', 't', 'win', 'in', 'Nov', '.', '@slone', '@amrightnow', '#Trump', 'https://t.', '…']
# ['"', 'Ten', 'big', 'problems', 'with', "#DonaldTrump's", "'", 'America', 'First', "'", 'foreign', 'policy', 'speech', '"', '-', '#Trump', '#ChrisChristie', '#gapol', 'https://t.co/bwz1U36lpO']
# ['"', 'Ten', 'big', 'problems', 'with', "#DonaldTrump's", "'", 'America', 'First', "'", 'foreign', 'policy', 'speech', '"', '-', '#Trump', '#ChrisChristie', '#gapol', 'https://t.co/bwz1U36lpO']
# ['@cenkuygur', 'if', "it's", '#hrc', 'vs', '.', '#trump', ',', 'I', 'may', 'have', 'to', 'vote', 'for', 'that', 'clown', ';', 'fewer', 'people', 'will', 'die', 'as', 'a', 'result', '.', '#BernieOrBust']
# ['@cenkuygur', 'if', "it's", '#hrc', 'vs', '.', '#trump', ',', 'I', 'may', 'have', 'to', 'vote', 'for', 'that', 'clown', ';', 'fewer', 'people', 'will', 'die', 'as', 'a', 'result', '.', '#BernieOrBust']
# ['RT', '@Campaign_Trump', ':', '#Trump', 'billionaire', 'is', 'staying', 'at', 'Holiday', 'Express', '.', "It's", 'shows', 'you', 'he', 'is', 'just', 'a', 'nice', 'plain', 'no', 'BS', 'down', 'to', 'earth', 'guy', '.', 'http', '…']
# ['RT', '@Campaign_Trump', ':', '#Trump', 'billionaire', 'is', 'staying', 'at', 'Holiday', 'Express', '.', "It's", 'shows', 'you', 'he', 'is', 'just', 'a', 'nice', 'plain', 'no', 'BS', 'down', 'to', 'earth', 'guy', '.', 'http', '…']
# ['RT', '@TrussElise', ':', '#Trump', 'Anyone', 'who', 'raised', 'kids', ',', 'like', 'the', 'Trump', 'kids', 'has', 'always', 'had', 'and', 'lived', 'by', 'conservative', 'values', '.', 'Just', 'saying', 'the', 'proof', 'i', '…']
# ['RT', '@TrussElise', ':', '#Trump', 'Anyone', 'who', 'raised', 'kids', ',', 'like', 'the', 'Trump', 'kids', 'has', 'always', 'had', 'and', 'lived', 'by', 'conservative', 'values', '.', 'Just', 'saying', 'the', 'proof', 'i', '…']
# ['RT', '@Campaign_Trump', ':', '#Trump', 'billionaire', 'is', 'staying', 'at', 'Holiday', 'Express', '.', "It's", 'shows', 'you', 'he', 'is', 'just', 'a', 'nice', 'plain', 'no', 'BS', 'down', 'to', 'earth', 'guy', '.', 'http', '…']
# ['RT', '@Campaign_Trump', ':', '#Trump', 'billionaire', 'is', 'staying', 'at', 'Holiday', 'Express', '.', "It's", 'shows', 'you', 'he', 'is', 'just', 'a', 'nice', 'plain', 'no', 'BS', 'down', 'to', 'earth', 'guy', '.', 'http', '…']
# ['RT', '@RickRWells', ':', 'Excitable', 'Ted', 'Cruz', 'Thrilled', ',', 'Amazed', 'By', 'Basketball', '"', 'Ring', '"', 'Height', 'https://t.co/xrVdGcDmT3', '#trump', '#trump2016', 'https://t.co/q05', '…']
# ['RT', '@RickRWells', ':', 'Excitable', 'Ted', 'Cruz', 'Thrilled', ',', 'Amazed', 'By', 'Basketball', '"', 'Ring', '"', 'Height', 'https://t.co/xrVdGcDmT3', '#trump', '#trump2016', 'https://t.co/q05', '…']
# ['@ConservEagleUSA', '#FlakeyMisstresFiorina', '#LyinTed', '#LooneyKasich', 'Get', '💰', '#PAY-OFFS', 'To', 'Cost', '#TRUMP', 'Delegates', '👉', 'have', '#CONVENTION', 'to', '👉', 'PIC', 'NEW', 'PREZ', '😕']
# ['@ConservEagleUSA', '#FlakeyMisstresFiorina', '#LyinTed', '#LooneyKasich', 'Get', '💰', '#PAY-OFFS', 'To', 'Cost', '#TRUMP', 'Delegates', '👉', 'have', '#CONVENTION', 'to', '👉', 'PIC', 'NEW', 'PREZ', '😕']
# ['RT', '@Lrihendry', ':', '"', 'Yes', 'it', 'was', '2008,', 'but', 'how', 'can', 'you', 'say', 'that', 'even', 'before', 'all', 'the', 'other', 'added', 'atrocities', 'since', 'then', '?', '"', '#INPrimary', '#Trump', 'https', ':/', '…']
# ['RT', '@Lrihendry', ':', '"', 'Yes', 'it', 'was', '2008,', 'but', 'how', 'can', 'you', 'say', 'that', 'even', 'before', 'all', 'the', 'other', 'added', 'atrocities', 'since', 'then', '?', '"', '#INPrimary', '#Trump', 'https', ':/', '…']
# ['RT', '@KLSouth', ':', 'Its', 'over', '#Cruz', '.', '.', '#Trump', 'https://t.co/AgHVCVkkmp']
# ['RT', '@KLSouth', ':', 'Its', 'over', '#Cruz', '.', '.', '#Trump', 'https://t.co/AgHVCVkkmp']
# ['RT', '@rossr122', ':', '#DonaldTrump', '#Trump', '#MakeAmericaGreatAgain', '#TrumpTrain', '#STOPGOPe', '#Women4Trump', '#AmericaFIRST', '#Indiana', 'https://t.co/7DO6Z5VObG']
# ['RT', '@rossr122', ':', '#DonaldTrump', '#Trump', '#MakeAmericaGreatAgain', '#TrumpTrain', '#STOPGOPe', '#Women4Trump', '#AmericaFIRST', '#Indiana', 'https://t.co/7DO6Z5VObG']
# ['Hahahah', 'YES', '!', "It's", 'FANTASTIC', '!', '#Trump', 'https://t.co/UpBlN2bldM']
# ['Hahahah', 'YES', '!', "It's", 'FANTASTIC', '!', '#Trump', 'https://t.co/UpBlN2bldM']
# ['RT', '@10thAmendment', ':', '#Trump', 'just', 'secured', 'a', 'pretty', 'solid', 'endorsement', 'in', 'the', 'state', 'of', '#Indiana', '.', '.', '.', 'legendary', 'Hoosiers', 'coach', 'Bobby', 'Knight', '.', 'http', '…']
# ['RT', '@10thAmendment', ':', '#Trump', 'just', 'secured', 'a', 'pretty', 'solid', 'endorsement', 'in', 'the', 'state', 'of', '#Indiana', '.', '.', '.', 'legendary', 'Hoosiers', 'coach', 'Bobby', 'Knight', '.', 'http', '…']
# ['RT', '@Twitturriffic', ':', '@AisleBBach', '@ericbolling', '#TeamTrump', '#butthurt', '#TrumpTrain', '#Trump2016', '#TRUMP', '#cruzcrew', '#carly', '#carlycruz', '#tedcruz', 'https', ':/', '…']
# ['RT', '@Twitturriffic', ':', '@AisleBBach', '@ericbolling', '#TeamTrump', '#butthurt', '#TrumpTrain', '#Trump2016', '#TRUMP', '#cruzcrew', '#carly', '#carlycruz', '#tedcruz', 'https', ':/', '…']
# ['RT', '@patrice_shoffie', ':', '#KellyFile', 'Too', 'funny', 'EVERY', 'WOMAN', 'I', 'KNOW', '"', 'WHICH', 'Are', 'MANY', '"', 'ARE', 'FOR', '#TRUMP', 'I', "DON'T", 'believe', 'the', "Media's", 'POLLING', '!', '!', '!']
# ['RT', '@patrice_shoffie', ':', '#KellyFile', 'Too', 'funny', 'EVERY', 'WOMAN', 'I', 'KNOW', '"', 'WHICH', 'Are', 'MANY', '"', 'ARE', 'FOR', '#TRUMP', 'I', "DON'T", 'believe', 'the', "Media's", 'POLLING', '!', '!', '!']
# ['Sorry', 'Newt', ',', 'America', 'wants', 'a', 'better', 'candidate', 'than', 'one', 'whose', 'only', 'qualification', 'is', 'being', 'able', 'to', 'say', '"', 'America', '"', '#Trump', 'https://t.co/haaAHApKUr']
# ['Sorry', 'Newt', ',', 'America', 'wants', 'a', 'better', 'candidate', 'than', 'one', 'whose', 'only', 'qualification', 'is', 'being', 'able', 'to', 'say', '"', 'America', '"', '#Trump', 'https://t.co/haaAHApKUr']
# ['RT', '@jdczeppelin', ':', '#1A', '#2A', '#MAGA', '#nevercruz', '#WakeUpAmerica', '#alwaystrump', '#StoptheSteal', '#trump', '#trumptrain', '#trump2016', 'https://t.co/DV9jygLTwk']
# ['RT', '@jdczeppelin', ':', '#1A', '#2A', '#MAGA', '#nevercruz', '#WakeUpAmerica', '#alwaystrump', '#StoptheSteal', '#trump', '#trumptrain', '#trump2016', 'https://t.co/DV9jygLTwk']
# ['RT', '@pegcamp78', ':', 'I', 'was', '100', '%', 'behind', '#Trump', 'yesterday', ',', 'but', 'now', '1,000', '%', 'for', 'him', 'after', 'brilliant', 'foreign', 'policy', 'speech', '.', 'Courage', '&', 'amp', ';', 'vision', '!', 'https', ':/', '/', '…']
# ['RT', '@pegcamp78', ':', 'I', 'was', '100', '%', 'behind', '#Trump', 'yesterday', ',', 'but', 'now', '1,000', '%', 'for', 'him', 'after', 'brilliant', 'foreign', 'policy', 'speech', '.', 'Courage', '&', 'amp', ';', 'vision', '!', 'https', ':/', '/', '…']
# ['RT', '@Trump2016Donald', ':', 'Donald', 'Trump', 'FULL', 'Townhall', 'Indiana', 'w', '/', 'Greta', 'Van', 'Guest', 'Bob', 'Knight', '-', '4', '/', '27', '/', '16', 'https://t.co/xTXyYy8JrO', '#Trump2016', '#Trump', '#', '…']
# ['RT', '@Trump2016Donald', ':', 'Donald', 'Trump', 'FULL', 'Townhall', 'Indiana', 'w', '/', 'Greta', 'Van', 'Guest', 'Bob', 'Knight', '-', '4', '/', '27', '/', '16', 'https://t.co/xTXyYy8JrO', '#Trump2016', '#Trump', '#', '…']
# ['RT', '@NatashaFatah', ':', '#BREAKING', '#Trump', ':', 'We', 'are', 'in', 'a', 'war', 'with', 'radical', 'Islam', '.', 'Obama', 'and', 'Clinton', 'cannot', 'even', 'say', 'the', 'words', '"', 'radical', 'Islam', '"', '.', '#Forei', '…']
# ['RT', '@NatashaFatah', ':', '#BREAKING', '#Trump', ':', 'We', 'are', 'in', 'a', 'war', 'with', 'radical', 'Islam', '.', 'Obama', 'and', 'Clinton', 'cannot', 'even', 'say', 'the', 'words', '"', 'radical', 'Islam', '"', '.', '#Forei', '…']
# ['RT', '@CharlesBivona', ':', 'He', 'said', "he's", 'gonna', 'vote', 'for', '#Trump', 'over', '#Clinton', 'because', "#Bernie's", 'Facebook', 'Pages', 'were', 'spammed', 'w', '/', '#porn', '.', 'https://t.co/kE', '…']
# ['RT', '@CharlesBivona', ':', 'He', 'said', "he's", 'gonna', 'vote', 'for', '#Trump', 'over', '#Clinton', 'because', "#Bernie's", 'Facebook', 'Pages', 'were', 'spammed', 'w', '/', '#porn', '.', 'https://t.co/kE', '…']
# ['@z0mgItsHutch', '#Trump']
# ['@z0mgItsHutch', '#Trump']
# ['RT', '@Campaign_Trump', ':', '#Trump', 'billionaire', 'is', 'staying', 'at', 'Holiday', 'Express', '.', "It's", 'shows', 'you', 'he', 'is', 'just', 'a', 'nice', 'plain', 'no', 'BS', 'down', 'to', 'earth', 'guy', '.', 'http', '…']
# ['RT', '@Campaign_Trump', ':', '#Trump', 'billionaire', 'is', 'staying', 'at', 'Holiday', 'Express', '.', "It's", 'shows', 'you', 'he', 'is', 'just', 'a', 'nice', 'plain', 'no', 'BS', 'down', 'to', 'earth', 'guy', '.', 'http', '…']
# ['RT', '@amrightnow', ':', '"', 'The', 'Real', 'Trump', '"', 'Trump', 'About', 'You', '"', 'Watch', 'Make', '#', '1', 'https://t.co/j58e8aacrE', '#Wisconsin', '#1A', '#2A', '#Trump', '#trump2016', 'https://t.co/0', '…']
# ['RT', '@amrightnow', ':', '"', 'The', 'Real', 'Trump', '"', 'Trump', 'About', 'You', '"', 'Watch', 'Make', '#', '1', 'https://t.co/j58e8aacrE', '#Wisconsin', '#1A', '#2A', '#Trump', '#trump2016', 'https://t.co/0', '…']
# ['RT', '@TRUMP_PREZ', ':', "#Indiana's", 'own', 'Bobby', 'Knight', 'endorses', 'Donald', '#Trump', 'Lets', '#MakeAmericaGreatAgain', 'VOTE', '#Trump2016', 'https://t.co/yjBSdIk1po']
# ['RT', '@TRUMP_PREZ', ':', "#Indiana's", 'own', 'Bobby', 'Knight', 'endorses', 'Donald', '#Trump', 'Lets', '#MakeAmericaGreatAgain', 'VOTE', '#Trump2016', 'https://t.co/yjBSdIk1po']
# ['RT', '@NorwoodTeaParty', ':', 'RT', '"', '@Lp_Maryana', '#CruzCrew', '#CruzFiorina2016', '#TrumpTrain', '#Trump', '#Trump2016', '#Cruz', '#GOP', '#WeThePeople', '#WakeUpAmerica', 'https', ':', '…']
# ['RT', '@NorwoodTeaParty', ':', 'RT', '"', '@Lp_Maryana', '#CruzCrew', '#CruzFiorina2016', '#TrumpTrain', '#Trump', '#Trump2016', '#Cruz', '#GOP', '#WeThePeople', '#WakeUpAmerica', 'https', ':', '…']
# ['#Trump', 'passes', 'Romney', '’', 's', 'popular', 'vote', 'total', ',', 'likely', 'to', 'break', 'GOP', 'record', '-', '#DonaldTrump', '#TrumpTrain', '#Women4Trump', 'https://t.co/rsjnBLzP8O']
# ['#Trump', 'passes', 'Romney', '’', 's', 'popular', 'vote', 'total', ',', 'likely', 'to', 'break', 'GOP', 'record', '-', '#DonaldTrump', '#TrumpTrain', '#Women4Trump', 'https://t.co/rsjnBLzP8O']
# ['RT', '@NgullenR', ':', '#YoungVoters', 'Overwhelmingly', 'Prefer', '#Clinton', 'Over', '#Trump', '-', '-', 'Poll', '.', 'https://t.co/sWN4To5wNW', '#Democrats', '#ImWithHer', '#USLatino', '#TNT', '…']
# ['RT', '@NgullenR', ':', '#YoungVoters', 'Overwhelmingly', 'Prefer', '#Clinton', 'Over', '#Trump', '-', '-', 'Poll', '.', 'https://t.co/sWN4To5wNW', '#Democrats', '#ImWithHer', '#USLatino', '#TNT', '…']
# ['RT', '@_AltRight_', ':', 'Confirmed', 'Nationalist', '!', '#Trump', 'will', 'be', 'the', 'best', 'POTUS', 'in', 'history', '.', '#AltRight', '#Trump2016', 'https://t.co/b5Z3CrTUXA']
# ['RT', '@_AltRight_', ':', 'Confirmed', 'Nationalist', '!', '#Trump', 'will', 'be', 'the', 'best', 'POTUS', 'in', 'history', '.', '#AltRight', '#Trump2016', 'https://t.co/b5Z3CrTUXA']
# ['@AndrewCMcCarthy', "#Trump's", '#ForeignPolicy', "doesn't", 'need', 'to', 'be', 'coherent', 'for', 'his', 'audience', '.', 'Important', 'words', 'cobbled', 'together', '#TrumpTowerOfBabel']
# ['@AndrewCMcCarthy', "#Trump's", '#ForeignPolicy', "doesn't", 'need', 'to', 'be', 'coherent', 'for', 'his', 'audience', '.', 'Important', 'words', 'cobbled', 'together', '#TrumpTowerOfBabel']
# ['RT', '@AnitaFinlay', ':', '#Trump', 'too', 'pigheaded', 'to', 'realize', 'all', 'women', 'care', 'abt', 'child', ',', 'health', '&', 'amp', ';', 'elder', 'care', ',', 'paid', 'leave', ',', '=', 'wages', ',', 'opportunity', 'https://t.', '…']
# ['RT', '@AnitaFinlay', ':', '#Trump', 'too', 'pigheaded', 'to', 'realize', 'all', 'women', 'care', 'abt', 'child', ',', 'health', '&', 'amp', ';', 'elder', 'care', ',', 'paid', 'leave', ',', '=', 'wages', ',', 'opportunity', 'https://t.', '…']
# ['@AnnCoulter', 'you', 'got', 'to', 'be', 'insane', '.', '#Trump', 'speech', 'was', 'pathetic', '.', 'I', 'cannot', 'believe', 'people', 'are', 'voting', 'for', 'this', 'clown', '.', 'https://t.co/LBO7F0I6gI']
# ['@AnnCoulter', 'you', 'got', 'to', 'be', 'insane', '.', '#Trump', 'speech', 'was', 'pathetic', '.', 'I', 'cannot', 'believe', 'people', 'are', 'voting', 'for', 'this', 'clown', '.', 'https://t.co/LBO7F0I6gI']
# ['RT', '@wtfnewsamerica', ':', '#Cruz', 'wants', 'a', 'woman', 'as', 'VP', '.', '#Trump', 'wants', 'a', 'woman', 'on', 'her', 'knees', '.', 'Not', 'a', 'tough', 'choice', 'on', 'how', 'to', '#vote', 'is', 'it', '?', '#INPrimary', 'http', '…']
# ['RT', '@wtfnewsamerica', ':', '#Cruz', 'wants', 'a', 'woman', 'as', 'VP', '.', '#Trump', 'wants', 'a', 'woman', 'on', 'her', 'knees', '.', 'Not', 'a', 'tough', 'choice', 'on', 'how', 'to', '#vote', 'is', 'it', '?', '#INPrimary', 'http', '…']
# ['@priyankachopra', 'u', 'r', 'just', 'an', 'entertainer', 'not', 'a', 'politician', 'also', 'i', 'think', 'he', 'may', 'be', 'right', '.', '.', '.', '#PriyankaChopra', '#Trump']
# ['@priyankachopra', 'u', 'r', 'just', 'an', 'entertainer', 'not', 'a', 'politician', 'also', 'i', 'think', 'he', 'may', 'be', 'right', '.', '.', '.', '#PriyankaChopra', '#Trump']
# ['RT', '@EndorsementsGOP', ':', 'Donald', 'J', 'Trump', 'has', 'Jumped', 'to', '987', 'Delegates', '4', '/', '28', '/', '2016', 'https://t.co/tNIZ2Pmb7d', '#IndianaPrimary', '#Trump', '#WV', '#CA', '#GOP', '#IN', 'h', '…']
# ['RT', '@EndorsementsGOP', ':', 'Donald', 'J', 'Trump', 'has', 'Jumped', 'to', '987', 'Delegates', '4', '/', '28', '/', '2016', 'https://t.co/tNIZ2Pmb7d', '#IndianaPrimary', '#Trump', '#WV', '#CA', '#GOP', '#IN', 'h', '…']
# ['RT', '@wtfnewsamerica', ':', '#Cruz', 'wants', 'a', 'woman', 'as', 'VP', '.', '#Trump', 'wants', 'a', 'woman', 'on', 'her', 'knees', '.', 'Not', 'a', 'tough', 'choice', 'on', 'how', 'to', '#vote', 'is', 'it', '?', '#INPrimary', 'http', '…']
# ['RT', '@wtfnewsamerica', ':', '#Cruz', 'wants', 'a', 'woman', 'as', 'VP', '.', '#Trump', 'wants', 'a', 'woman', 'on', 'her', 'knees', '.', 'Not', 'a', 'tough', 'choice', 'on', 'how', 'to', '#vote', 'is', 'it', '?', '#INPrimary', 'http', '…']
# ["That's", 'how', '#', 'O', 'ROLLS', 'fun', 'games', 'golf', 'celebs', 'always', 'come', 'first', 'before', 'crisis', '&', 'amp', ';', 'Country', '!', '#Trump', '#AmericaFirst', 'Always', '‼', '️', 'https://t.co/PdeVjO7RsI']
# ["That's", 'how', '#', 'O', 'ROLLS', 'fun', 'games', 'golf', 'celebs', 'always', 'come', 'first', 'before', 'crisis', '&', 'amp', ';', 'Country', '!', '#Trump', '#AmericaFirst', 'Always', '‼', '️', 'https://t.co/PdeVjO7RsI']
# ["I'm", 'not', '#GOPe', 'but', 'feel', 'estblshmnt', 'shld', 'do', 'more', '2', 'stop', '#Trump', '.', '@Reince', '@krauthammer', '@KarlRove', '#NeverTrump']
# ["I'm", 'not', '#GOPe', 'but', 'feel', 'estblshmnt', 'shld', 'do', 'more', '2', 'stop', '#Trump', '.', '@Reince', '@krauthammer', '@KarlRove', '#NeverTrump']
# ['RT', '@Always_Trump', ':', 'Trump', 'absolutely', 'OBLITERATING', '#LyinTed', 'with', 'Christian', 'voters', '#TrumpTrain', '#Trump', '#Trump2016', 'https://t.co/1WlRr7QtsQ']
# ['RT', '@Always_Trump', ':', 'Trump', 'absolutely', 'OBLITERATING', '#LyinTed', 'with', 'Christian', 'voters', '#TrumpTrain', '#Trump', '#Trump2016', 'https://t.co/1WlRr7QtsQ']
# ['RT', '@Jarboni72', ':', 'Bobby', 'Knight', ',', 'the', 'king', 'of', 'Indiana', 'basketball', ',', '2', 'campaign', 'with', '#Trump', '.', 'The', 'momentum', 'is', 'building', 'toward', 'a', 'big', 'victory', '!', 'https', ':/', '…']
# ['RT', '@Jarboni72', ':', 'Bobby', 'Knight', ',', 'the', 'king', 'of', 'Indiana', 'basketball', ',', '2', 'campaign', 'with', '#Trump', '.', 'The', 'momentum', 'is', 'building', 'toward', 'a', 'big', 'victory', '!', 'https', ':/', '…']
# ['RT', '@Campaign_Trump', ':', '#Trump', 'billionaire', 'is', 'staying', 'at', 'Holiday', 'Express', '.', "It's", 'shows', 'you', 'he', 'is', 'just', 'a', 'nice', 'plain', 'no', 'BS', 'down', 'to', 'earth', 'guy', '.', 'http', '…']
# ['RT', '@Campaign_Trump', ':', '#Trump', 'billionaire', 'is', 'staying', 'at', 'Holiday', 'Express', '.', "It's", 'shows', 'you', 'he', 'is', 'just', 'a', 'nice', 'plain', 'no', 'BS', 'down', 'to', 'earth', 'guy', '.', 'http', '…']
# ['RT', '@MichaelaAngelaD', ':', 'Check', 'my', 'girls', 'face', 'when', 'ole', 'dude', 'said', '#Trump', 'won', '13', 'COLONIES', '@angela_rye', 'on', '@donlemon', '@CNN', 'https://t.co/LJ3YVLd6eh']
# ['RT', '@MichaelaAngelaD', ':', 'Check', 'my', 'girls', 'face', 'when', 'ole', 'dude', 'said', '#Trump', 'won', '13', 'COLONIES', '@angela_rye', 'on', '@donlemon', '@CNN', 'https://t.co/LJ3YVLd6eh']
# ['RT', '@Campaign_Trump', ':', '#Trump', 'billionaire', 'is', 'staying', 'at', 'Holiday', 'Express', '.', "It's", 'shows', 'you', 'he', 'is', 'just', 'a', 'nice', 'plain', 'no', 'BS', 'down', 'to', 'earth', 'guy', '.', 'http', '…']
# ['RT', '@Campaign_Trump', ':', '#Trump', 'billionaire', 'is', 'staying', 'at', 'Holiday', 'Express', '.', "It's", 'shows', 'you', 'he', 'is', 'just', 'a', 'nice', 'plain', 'no', 'BS', 'down', 'to', 'earth', 'guy', '.', 'http', '…']
# ['RT', '@NgullenR', ':', 'Current', ',', 'Former', 'Soldiers', 'Say', '#Trump', 'Would', 'Be', 'an', 'Epic', 'Disaster', 'as', 'Commander-in-Chief', '.', 'https://t.co/Rz1B2Djjpz', '#DemocratsUnite', '…']
# ['RT', '@NgullenR', ':', 'Current', ',', 'Former', 'Soldiers', 'Say', '#Trump', 'Would', 'Be', 'an', 'Epic', 'Disaster', 'as', 'Commander-in-Chief', '.', 'https://t.co/Rz1B2Djjpz', '#DemocratsUnite', '…']
# ['RT', '@CharlesBivona', ':', 'Masters', 'degree', 'in', '#history', ',', 'and', 'she', 'says', "she'll", 'vote', 'for', '#Trump', 'because', '"', 'he', 'did', 'good', '"', 'on', 'The', 'Apprentice', '.', 'https://t.co/sD', '…']
# ['RT', '@CharlesBivona', ':', 'Masters', 'degree', 'in', '#history', ',', 'and', 'she', 'says', "she'll", 'vote', 'for', '#Trump', 'because', '"', 'he', 'did', 'good', '"', 'on', 'The', 'Apprentice', '.', 'https://t.co/sD', '…']
# ['RT', '@_AltRight_', ':', 'Confirmed', 'Nationalist', '!', '#Trump', 'will', 'be', 'the', 'best', 'POTUS', 'in', 'history', '.', '#AltRight', '#Trump2016', 'https://t.co/b5Z3CrTUXA']
# ['RT', '@_AltRight_', ':', 'Confirmed', 'Nationalist', '!', '#Trump', 'will', 'be', 'the', 'best', 'POTUS', 'in', 'history', '.', '#AltRight', '#Trump2016', 'https://t.co/b5Z3CrTUXA']
# ['RT', '@GypsiSin', ':', 'OMG', '!', '😂', '@tedcruz', '&', 'amp', ';', '@JohnKasich', 'have', 'a', 'BROMANCE', ',', 'I', 'think', "it's", 'fucked', 'up', 'the', 'dirty', 'shit', 'our', 'GOP', 'IS', 'ALLOWING', '.', "It's", 'obvious', 'who', 'the', 'b', '…']
# ['RT', '@GypsiSin', ':', 'OMG', '!', '😂', '@tedcruz', '&', 'amp', ';', '@JohnKasich', 'have', 'a', 'BROMANCE', ',', 'I', 'think', "it's", 'fucked', 'up', 'the', 'dirty', 'shit', 'our', 'GOP', 'IS', 'ALLOWING', '.', "It's", 'obvious', 'who', 'the', 'b', '…']
# ['RT', '@EndorsementsGOP', ':', 'Donald', 'J', 'Trump', 'has', 'Jumped', 'to', '987', 'Delegates', '4', '/', '28', '/', '2016', 'https://t.co/tNIZ2Pmb7d', '#IndianaPrimary', '#Trump', '#WV', '#CA', '#GOP', '#IN', 'h', '…']
# ['RT', '@EndorsementsGOP', ':', 'Donald', 'J', 'Trump', 'has', 'Jumped', 'to', '987', 'Delegates', '4', '/', '28', '/', '2016', 'https://t.co/tNIZ2Pmb7d', '#IndianaPrimary', '#Trump', '#WV', '#CA', '#GOP', '#IN', 'h', '…']
# ['RT', '@trumpemall', ':', '#MittRomney', '@MittRomney', '#Trump', 'https://t.co/e7OcEQR4pm']
# ['RT', '@trumpemall', ':', '#MittRomney', '@MittRomney', '#Trump', 'https://t.co/e7OcEQR4pm']
# ['RT', '@Always_Trump', ':', 'Rare', 'colonial', 'Trump', 'for', 'winning', 'in', 'the', 'original', '13', 'colonies', '#RareTrump', '#Trump', '#Trump2016', 'https://t.co/07ZpCANhnO']
# ['RT', '@Always_Trump', ':', 'Rare', 'colonial', 'Trump', 'for', 'winning', 'in', 'the', 'original', '13', 'colonies', '#RareTrump', '#Trump', '#Trump2016', 'https://t.co/07ZpCANhnO']
# ['RT', '@trump_world', ':', 'Colorado', 'returning', 'to', 'Presidential', 'Primary', 'thanks', 'to', '@realDonaldTrump', '#Trump', '#Trump2016', '#MakeAmericaGreatAgain', 'https://t.c', '…']
# ['RT', '@trump_world', ':', 'Colorado', 'returning', 'to', 'Presidential', 'Primary', 'thanks', 'to', '@realDonaldTrump', '#Trump', '#Trump2016', '#MakeAmericaGreatAgain', 'https://t.c', '…']
# ['#CA', '#California', '#IN', '#Indiana', '#NJ', '#NewJersey', '#WV', '#WestVirginia', '#SD', '#SouthDakota', '#NE', '#OR', '#WA', '#MT', '#WY', '#NM', '#Trump', 'https://t.co/Sd3gh3jBYz']
# ['#CA', '#California', '#IN', '#Indiana', '#NJ', '#NewJersey', '#WV', '#WestVirginia', '#SD', '#SouthDakota', '#NE', '#OR', '#WA', '#MT', '#WY', '#NM', '#Trump', 'https://t.co/Sd3gh3jBYz']
# ['@DanScavino', '@BentleyforTrump', '@kupajo322', '@JaredWyand', '@TruthisAll', 'WE', 'LOVE', '#TRUMP', '#MAKEAMERICAGREATAGAIN', '✨', '🇺', '🇸', 'https://t.co/VnjGO5yuNv']
# ['@DanScavino', '@BentleyforTrump', '@kupajo322', '@JaredWyand', '@TruthisAll', 'WE', 'LOVE', '#TRUMP', '#MAKEAMERICAGREATAGAIN', '✨', '🇺', '🇸', 'https://t.co/VnjGO5yuNv']
# ['All', 'the', '#shit', 'we', '#invent', '#create', '#reinvent', '#remake', '&', 'amp', ';', 'we', 'R', 'stuck', 'on', '#Gas', '#Gasoline', '#Oil', '#MiddleEast', '#Clinton', '#Obama', '#Sanders', '#Trump', '#Cruz']
# ['All', 'the', '#shit', 'we', '#invent', '#create', '#reinvent', '#remake', '&', 'amp', ';', 'we', 'R', 'stuck', 'on', '#Gas', '#Gasoline', '#Oil', '#MiddleEast', '#Clinton', '#Obama', '#Sanders', '#Trump', '#Cruz']
# ["Can't", 'wait', 'to', 'see', '#Trump', 'prez', 'of', 'the', '#USA', ',', 'will', 'be', 'constant', 'entertainment']
# ["Can't", 'wait', 'to', 'see', '#Trump', 'prez', 'of', 'the', '#USA', ',', 'will', 'be', 'constant', 'entertainment']
# ['RT', '@HartmannVet79', ':', 'Listened', 'to', '#Trump', 'foreign', 'policy', 'speech', 'tonight', '&', 'amp', ';', 'for', 'the', '1', 'st', 'time', 'in', 'many', 'yrs', 'I', 'feel', 'we', 'have', 'a', 'candidate', 'ready', 'to', 'toe', '…']
# ['RT', '@HartmannVet79', ':', 'Listened', 'to', '#Trump', 'foreign', 'policy', 'speech', 'tonight', '&', 'amp', ';', 'for', 'the', '1', 'st', 'time', 'in', 'many', 'yrs', 'I', 'feel', 'we', 'have', 'a', 'candidate', 'ready', 'to', 'toe', '…']
# ['RT', '@KarenMBlaisdell', ':', '@WayneRoot', '@rharrisonfries', 'funny', '.', '.', '.', 'all', 'I', 'had', 'to', 'hear', 'was', 'America', 'and', 'Americans', 'first', 'and', 'I', 'was', 'sold', '.', '#Trump']
# ['RT', '@KarenMBlaisdell', ':', '@WayneRoot', '@rharrisonfries', 'funny', '.', '.', '.', 'all', 'I', 'had', 'to', 'hear', 'was', 'America', 'and', 'Americans', 'first', 'and', 'I', 'was', 'sold', '.', '#Trump']
# ['RT', '@Shadz66Shadz6t6', ':', '#Bernie', 'is', '328', 'Delegates', 'behind', '#HRC', ',', 'who', '#tRUMP', 'may', '"', 'beat', 'bigly', '"', 'but', "#Sanders'll", 'clean', 'his', 'clock', '!', '#SuperDelegates', '?', '!', 'h', '…']
# ['RT', '@Shadz66Shadz6t6', ':', '#Bernie', 'is', '328', 'Delegates', 'behind', '#HRC', ',', 'who', '#tRUMP', 'may', '"', 'beat', 'bigly', '"', 'but', "#Sanders'll", 'clean', 'his', 'clock', '!', '#SuperDelegates', '?', '!', 'h', '…']
# ['RT', '@KNP2BP', ':', 'The', 'failed', ',', 'unholy', 'alliance', 'b', '/', 't', 'Dumb', '&', 'amp', ';', 'Dumber', 'gave', 'us', 'insight', 'into', 'their', 'leadership', 'skills', '!', 'OOPS', '!', 'YUGE', 'FAIL', '!', '#Trump', 'https://t.c', '…']
# ['RT', '@KNP2BP', ':', 'The', 'failed', ',', 'unholy', 'alliance', 'b', '/', 't', 'Dumb', '&', 'amp', ';', 'Dumber', 'gave', 'us', 'insight', 'into', 'their', 'leadership', 'skills', '!', 'OOPS', '!', 'YUGE', 'FAIL', '!', '#Trump', 'https://t.c', '…']
# ['RT', '@trump2016fan', ':', 'Horror', ':', 'Fiorina', '"', "I'm", 'Fine', 'with', 'a', 'Muslim', 'President', '"', 'https://t.co/aubmv1X2V1', '#INPrimary', '#Indiana', '#Trump', '#CAPrimary', 'https', ':/', '…']
# ['RT', '@trump2016fan', ':', 'Horror', ':', 'Fiorina', '"', "I'm", 'Fine', 'with', 'a', 'Muslim', 'President', '"', 'https://t.co/aubmv1X2V1', '#INPrimary', '#Indiana', '#Trump', '#CAPrimary', 'https', ':/', '…']
# ['RT', '@PatriotByGod', ':', 'This', 'never', 'gets', 'old', '!', '!', '#IndianaPrimary', 'it', 'is', 'your', 'turn', '!', "Let's", 'finish', 'this', 'and', 'go', 'beat', 'Hillary', '!', '@AppSame', '#Trump', 'https://t.c', '…']
# ['RT', '@PatriotByGod', ':', 'This', 'never', 'gets', 'old', '!', '!', '#IndianaPrimary', 'it', 'is', 'your', 'turn', '!', "Let's", 'finish', 'this', 'and', 'go', 'beat', 'Hillary', '!', '@AppSame', '#Trump', 'https://t.c', '…']
# ['RT', '@CharlesBivona', ':', 'The', '@YouTube', 'commercial', 'that', 'runs', 'during', "#Trump's", 'foreign', 'policy', 'speech', ':', 'Come', 'to', 'Canada', '!', 'Hahaha', '!', 'Ouch', '.', '#njpoet', '#amwriting']
# ['RT', '@CharlesBivona', ':', 'The', '@YouTube', 'commercial', 'that', 'runs', 'during', "#Trump's", 'foreign', 'policy', 'speech', ':', 'Come', 'to', 'Canada', '!', 'Hahaha', '!', 'Ouch', '.', '#njpoet', '#amwriting']
# ['RT', '@CharlesBivona', ':', 'Now', 'watching', 'Donald', '#Trump', 'speak', 'on', 'foreign', 'policy', '.', 'https://t.co/6IyS9PbqUk', '#amreading', '#amwriting']
# ['RT', '@CharlesBivona', ':', 'Now', 'watching', 'Donald', '#Trump', 'speak', 'on', 'foreign', 'policy', '.', 'https://t.co/6IyS9PbqUk', '#amreading', '#amwriting']
# ['RT', '@jdczeppelin', ':', '#1A', '#2A', '#MAGA', '#nevercruz', '#WakeUpAmerica', '#alwaystrump', '#StoptheSteal', '#trump', '#trumptrain', '#trump2016', 'https://t.co/aU9Jl6I0tK']
# ['RT', '@jdczeppelin', ':', '#1A', '#2A', '#MAGA', '#nevercruz', '#WakeUpAmerica', '#alwaystrump', '#StoptheSteal', '#trump', '#trumptrain', '#trump2016', 'https://t.co/aU9Jl6I0tK']
# ['RT', '@Always_Trump', ':', '#Trump', 'will', 'be', 'the', '45', 'th', 'President', 'of', 'the', 'United', 'States', ',', 'Hillary', 'is', 'going', 'to', 'Prison', ',', 'Bernie', 'is', 'a', 'Cuck', ',', 'and', 'the', 'Wall', 'just', 'g', '…']
# ['RT', '@Always_Trump', ':', '#Trump', 'will', 'be', 'the', '45', 'th', 'President', 'of', 'the', 'United', 'States', ',', 'Hillary', 'is', 'going', 'to', 'Prison', ',', 'Bernie', 'is', 'a', 'Cuck', ',', 'and', 'the', 'Wall', 'just', 'g', '…']
# ['RT', '@GerbusJames', ':', '#Trump', 'will', 'be', 'a', 'great', 'President', '!', "It's", 'time', 'that', 'the', 'US', 'has', 'a', 'strong', '&', 'amp', ';', 'commanding', 'voice', '!', 'Cruz', '&', 'amp', ';', 'Kasick', 'are', 'pathetic', '.', 'https', '…']
# ['RT', '@GerbusJames', ':', '#Trump', 'will', 'be', 'a', 'great', 'President', '!', "It's", 'time', 'that', 'the', 'US', 'has', 'a', 'strong', '&', 'amp', ';', 'commanding', 'voice', '!', 'Cruz', '&', 'amp', ';', 'Kasick', 'are', 'pathetic', '.', 'https', '…']
# ['RT', '@Lp_Maryana', ':', '#CruzCrew', '#CruzFiorina2016', '#TrumpTrain', '#Trump', '#Trump2016', '#Cruz', '#GOP', '#WeThePeople', '#WakeUpAmerica', '@ChuckNellis', 'https://t.co/Y', '…']
# ['RT', '@Lp_Maryana', ':', '#CruzCrew', '#CruzFiorina2016', '#TrumpTrain', '#Trump', '#Trump2016', '#Cruz', '#GOP', '#WeThePeople', '#WakeUpAmerica', '@ChuckNellis', 'https://t.co/Y', '…']
# ['Oof', ',', "#DonaldTrump's", 'mispronunciation', 'of', 'Tanzania', 'is', 'painful', '.', 'Just', 'saw', '/', 'heard', '.', '#Trump', '#p2', '#Election2016', '#tcot', '#NeverTrump']
# ['Oof', ',', "#DonaldTrump's", 'mispronunciation', 'of', 'Tanzania', 'is', 'painful', '.', 'Just', 'saw', '/', 'heard', '.', '#Trump', '#p2', '#Election2016', '#tcot', '#NeverTrump']
# ['#TrumpTrain', '#MAGA', '#Trump2016', '#TrumpRally', '#WomenForTrump', '#IN4Trump', '#TrumpArmy', '#IndianaPrimary', '#TrumpNation', '#Trump', 'https://t.co/me0RGgW9Q9']
# ['#TrumpTrain', '#MAGA', '#Trump2016', '#TrumpRally', '#WomenForTrump', '#IN4Trump', '#TrumpArmy', '#IndianaPrimary', '#TrumpNation', '#Trump', 'https://t.co/me0RGgW9Q9']
# ['WTH', 'Teddy', '!', 'You', 'already', 'negotiaTed', 'that', 'one', '.', 'You', 'own', 'it', '.', '#Trump', 'will', 'have', 'to', 'fix', 'your', 'mess', '.', '#BusTed', '!', 'https://t.co/7p9vI85YXQ']
# ['WTH', 'Teddy', '!', 'You', 'already', 'negotiaTed', 'that', 'one', '.', 'You', 'own', 'it', '.', '#Trump', 'will', 'have', 'to', 'fix', 'your', 'mess', '.', '#BusTed', '!', 'https://t.co/7p9vI85YXQ']
# ['@ChanceKucera', 'Are', 'CruzFans', 'so', 'lazy', 'they', "won't", 'research', 'for', 'themselves', ',', 'just', 'echo', 'chambers', '?', '@tedcruz', 'took', '#Trump', 'dollars', 'twice', ',', "let's", 'talk', '.']
# ['@ChanceKucera', 'Are', 'CruzFans', 'so', 'lazy', 'they', "won't", 'research', 'for', 'themselves', ',', 'just', 'echo', 'chambers', '?', '@tedcruz', 'took', '#Trump', 'dollars', 'twice', ',', "let's", 'talk', '.']
# ['#Trump', 'billionaire', 'is', 'staying', 'at', 'Holiday', 'Express', '.', "It's", 'shows', 'you', 'he', 'is', 'just', 'a', 'nice', 'plain', 'no', 'BS', 'down', 'to', 'earth', 'guy', '.', 'https://t.co/Nayyhhonr9']
# ['#Trump', 'billionaire', 'is', 'staying', 'at', 'Holiday', 'Express', '.', "It's", 'shows', 'you', 'he', 'is', 'just', 'a', 'nice', 'plain', 'no', 'BS', 'down', 'to', 'earth', 'guy', '.', 'https://t.co/Nayyhhonr9']
# ["'", 'Best', 'Person', 'to', 'Lead', 'America', 'Back', "'", ':', 'Bobby', 'Knight', 'On', 'Why', "He's", 'Behind', '#Trump', 'https://t.co/Wm85SlWNER', '#AmericaFirst', '#Trump2016', '#TrumpTrain']
# ["'", 'Best', 'Person', 'to', 'Lead', 'America', 'Back', "'", ':', 'Bobby', 'Knight', 'On', 'Why', "He's", 'Behind', '#Trump', 'https://t.co/Wm85SlWNER', '#AmericaFirst', '#Trump2016', '#TrumpTrain']
# ['RT', '@RickRWells', ':', 'Excitable', 'Ted', 'Cruz', 'Thrilled', ',', 'Amazed', 'By', 'Basketball', '"', 'Ring', '"', 'Height', 'https://t.co/xrVdGcDmT3', '#trump', '#trump2016', 'https://t.co/q05', '…']
# ['RT', '@RickRWells', ':', 'Excitable', 'Ted', 'Cruz', 'Thrilled', ',', 'Amazed', 'By', 'Basketball', '"', 'Ring', '"', 'Height', 'https://t.co/xrVdGcDmT3', '#trump', '#trump2016', 'https://t.co/q05', '…']
# ['RT', '@EricTrump', ':', 'This', 'is', 'so', 'sad', '!', '#Wisconsin', 'please', '#VOTE', 'and', 'help', 'us', 'stop', 'this', 'awful', 'decline', '#MakeAmericaGreatAgain', '#Trump', '#Trump2016', 'https', ':/', '…']
# ['RT', '@EricTrump', ':', 'This', 'is', 'so', 'sad', '!', '#Wisconsin', 'please', '#VOTE', 'and', 'help', 'us', 'stop', 'this', 'awful', 'decline', '#MakeAmericaGreatAgain', '#Trump', '#Trump2016', 'https', ':/', '…']
# ['@FoxNews', '@realDonaldTrump', '#yes', '#trump', '2016']
# ['@FoxNews', '@realDonaldTrump', '#yes', '#trump', '2016']
# ['Now', 'Every', 'Corner', 'Of', 'The', 'World', 'Has', 'Joined', 'Forces', 'To', 'Destroy', '#TRUMP', 'What', 'Happens', '?', 'HE', 'WINS', 'BIGGER', 'Tell', 'Me', 'Thats', 'Human', '&', 'amp', ';', 'I', 'Will', 'Laugh', 'At', 'You']
# ['Now', 'Every', 'Corner', 'Of', 'The', 'World', 'Has', 'Joined', 'Forces', 'To', 'Destroy', '#TRUMP', 'What', 'Happens', '?', 'HE', 'WINS', 'BIGGER', 'Tell', 'Me', 'Thats', 'Human', '&', 'amp', ';', 'I', 'Will', 'Laugh', 'At', 'You']
# ['@AdamIShackleton', 'Thank', 'you', 'Gov', 'Perry', ',', 'for', 'siding', 'with', '"', 'The', 'People', '"', '!', 'Go', '#Trump']
# ['@AdamIShackleton', 'Thank', 'you', 'Gov', 'Perry', ',', 'for', 'siding', 'with', '"', 'The', 'People', '"', '!', 'Go', '#Trump']
# ['RT', '@rossr122', ':', '#DonaldTrump', '#Trump', '#MakeAmericaGreatAgain', '#TrumpTrain', '#STOPGOPe', '#Women4Trump', '#AmericaFIRST', '#Indiana', 'https://t.co/7DO6Z5VObG']
# ['RT', '@rossr122', ':', '#DonaldTrump', '#Trump', '#MakeAmericaGreatAgain', '#TrumpTrain', '#STOPGOPe', '#Women4Trump', '#AmericaFIRST', '#Indiana', 'https://t.co/7DO6Z5VObG']
# ['RT', '@GerbusJames', ':', '#Trump', 'will', 'be', 'a', 'great', 'President', '!', "It's", 'time', 'that', 'the', 'US', 'has', 'a', 'strong', '&', 'amp', ';', 'commanding', 'voice', '!', 'Cruz', '&', 'amp', ';', 'Kasick', 'are', 'pathetic', '.', 'https', '…']
# ['RT', '@GerbusJames', ':', '#Trump', 'will', 'be', 'a', 'great', 'President', '!', "It's", 'time', 'that', 'the', 'US', 'has', 'a', 'strong', '&', 'amp', ';', 'commanding', 'voice', '!', 'Cruz', '&', 'amp', ';', 'Kasick', 'are', 'pathetic', '.', 'https', '…']
# ['@realDonaldTrump', 'INDIANA', 'WILL', 'BE', 'OURS', '#BobbyKnight', 'recognizes', 'talent', 'like', 'no', 'other', 'Get', 'your', 'friends', 'to', 'vote', '#trump', '#TrumpForeignPolicy', '#nra']
# ['@realDonaldTrump', 'INDIANA', 'WILL', 'BE', 'OURS', '#BobbyKnight', 'recognizes', 'talent', 'like', 'no', 'other', 'Get', 'your', 'friends', 'to', 'vote', '#trump', '#TrumpForeignPolicy', '#nra']

# %%
#Count the terms
import operator 
import json
from collections import Counter
 
fname = 'tweets-0001.json'
with open(fname, 'r') as f:
    count_all = Counter()
    for line in f:
        tweet = json.loads(line)
        count_all.update(preprocess(tweet['text']))
    # Print the first 5 most frequent words
    print(count_all.most_common(5))
# Out:
# [(',', 26), (':', 24), ('we', 20), ('#DiverseDH', 18), ('!', 16)]

# %% [markdown]
# ### Tokenization failure example

# %%
from nltk.tokenize import word_tokenize
 
fake_tweet = "RT @symulation: just an example I'd like to share! :D http://example.com #NLP #NLTK"
print(word_tokenize(fake_tweet))
# Out:
# ['RT', '@', 'symulation', ':', 'just', 'an', 'example', 'I', "'d", 'like', 'to', 'share', '!', ':', 'D', 'http', ':', '//example.com', '#', 'NLP', '#', 'NLTK']

# %% [markdown]
# ### A pre-written text preprocessor from [this blog](https://marcobonzanini.com/2015/03/09/mining-twitter-data-with-python-part-2/)
#
# It is unlikely that you'll need to do anything with this preprocessor except copy it in-line with our code and/or run it whenever this notebook is opened.

# %%
#Instantiate a text pre-processor
import re
 
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens

# %%
#Task Description: load a corpus of tweets and print a barplot of the most frequently used terms

#Open the file
inFile = open('tweets-0001.json')
#for line in inFile:
#    print(line)

#Load the data from the file into a variable
import json

line = inFile.readline() # read only the first tweet/line
tweet = json.loads(line) # load it as Python dict
# this print is nice for showing the content of a tweet
#print(json.dumps(tweet, indent=4)) # pretty-print

#Slice up the body text of the tweets
from nltk.tokenize import word_tokenize
 
#tweet = 'RT @marcobonzanini: just an example! :D http://example.com #NLP'
print(word_tokenize(tweet['text'])) # chops up the tweet.  this is done badly.

#Instantiate a text pre-processor
import re
 
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens
 
print(preprocess(tweet['text']))

#Count the terms
import operator 
import json
from collections import Counter
 
fname = 'tweets-0001.json'
with open(fname, 'r') as f:
    count_all = Counter()
    for line in f:
        tweet = json.loads(line)
        # Create a list with all the terms
        terms_all = [term for term in preprocess(tweet['text'])]
        # Update the counter
        count_all.update(terms_all)
    # Print the first 5 most frequent words
    print(count_all.most_common(5))

#This gives us mostly junk though so we need to remove stopwords.
from nltk.corpus import stopwords
import string
 
punctuation = list(string.punctuation)
print(punctuation)
stop = stopwords.words('english') + punctuation + ['rt', 'via', 'RT', '…']

with open(fname, 'r') as f:
    count_all = Counter()
    for line in f:
        tweet = json.loads(line)
        # Create a list with all the terms
        terms_stop = [term for term in preprocess(tweet['text']) if term not in stop]
        # Update the counter
        count_all.update(terms_stop)
    # Print the first 5 most frequent words
    print (type(dict(count_all)))
    print(count_all.most_common(5))   
    
"""
# Count terms only once, equivalent to Document Frequency
terms_single = set(terms_all)
# Count hashtags only
terms_hash = [term for term in preprocess(tweet['text']) 
              if term.startswith('#')]
# Count terms only (no hashtags, no mentions)
terms_only = [term for term in preprocess(tweet['text']) 
    if term not in stop 
    and not term.startswith(('#', '@'))] 
    # mind the ((double brackets))
    # startswith() takes a tuple (not a list) if 
    # we pass a list of inputs
"""


#Produce the chart
# Print the current version of the chart
# %matplotlib inline
count_all_dict = dict(count_all.most_common(5))
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 6))
plt.bar(range(len(count_all_dict)), count_all_dict.values(), align='center')
plt.xticks(range(len(count_all_dict)), list(count_all_dict.keys()),rotation='vertical')

plt.show()

#Close everything
inFile.close()
# Out:
# Thu Apr 14 16:27:01 +0000 2016
# ['RT', '@', 'csdhschn', ':', 'Today', ',', 'we', 'launch', '#', 'DiverseDH', ',', '&', 'amp', ';', 'we', 'are', 'asking', 'for', 'help', 'from', '#', 'digitalhumanities', 'folks', '!', 'Please', 'share', 'and', 'contribute', ':', 'https', ':', '//t.c…']
# ['RT', '@csdhschn', ':', 'Today', ',', 'we', 'launch', '#DiverseDH', ',', '&', 'amp', ';', 'we', 'are', 'asking', 'for', 'help', 'from', '#digitalhumanities', 'folks', '!', 'Please', 'share', 'and', 'contribute', ':', 'https://t.c', '…']
# [(',', 26), (':', 24), ('we', 20), ('#DiverseDH', 18), ('!', 16)]
# ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~']
# <class 'dict'>
# [('#DiverseDH', 18), ('@csdhschn', 15), ('launch', 10), ('Today', 10), ('Please', 10)]
